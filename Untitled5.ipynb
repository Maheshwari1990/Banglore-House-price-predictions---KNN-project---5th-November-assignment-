# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib 
matplotlib.rcParams["figure.figsize"] = (20,10)

# %%
df1 = pd.read_csv("C:/Users/Admin/Documents/bangalore house price prediction OHE-data.csv")
df1.head()
# Out:
#    bath  balcony  price  total_sqft_int  bhk  price_per_sqft  \
# 0     3      2.0  150.0          1672.0    3     8971.291866
# 1     3      3.0  149.0          1750.0    3     8514.285714
# 2     3      2.0  150.0          1750.0    3     8571.428571
# 3     2      2.0   40.0          1250.0    2     3200.000000
# 4     2      2.0   83.0          1200.0    2     6916.666667
#
#    area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                              1                        0
# 1                              0                        1
# 2                              1                        0
# 3                              1                        0
# 4                              0                        0
#
#    area_typePlot  Area  availability_Ready To Move  ...  \
# 0                    0                           1  ...
# 1                    0                           1  ...
# 2                    0                           1  ...
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df1.shape
# Out:
# (7120, 108)

# %%
df1.columns
# Out:
# Index(['bath', 'balcony', 'price', 'total_sqft_int', 'bhk', 'price_per_sqft',
#        'area_typeSuper built-up  Area', 'area_typeBuilt-up  Area',
#        'area_typePlot  Area', 'availability_Ready To Move',
#        ...
#        'location_Kalena Agrahara', 'location_Horamavu Agara',
#        'location_Vidyaranyapura', 'location_BTM 2nd Stage',
#        'location_Hebbal Kempapura', 'location_Hosur Road',
#        'location_Horamavu Banaswadi', 'location_Domlur',
#        'location_Mahadevpura', 'location_Tumkur Road'],
#       dtype='object', length=108)

# %%
df1.isnull().sum()
# Out:
# bath                           0
# balcony                        0
# price                          0
# total_sqft_int                 0
# bhk                            0
#                               ..
# location_Hosur Road            0
# location_Horamavu Banaswadi    0
# location_Domlur                0
# location_Mahadevpura           0
# location_Tumkur Road           0
# Length: 108, dtype: int64

# %%
df2=df1.dropna()
df2.isnull().sum()
# Out:
# bath                           0
# balcony                        0
# price                          0
# total_sqft_int                 0
# bhk                            0
#                               ..
# location_Hosur Road            0
# location_Horamavu Banaswadi    0
# location_Domlur                0
# location_Mahadevpura           0
# location_Tumkur Road           0
# Length: 108, dtype: int64

# %%
df2.head()
# Out:
#    bath  balcony  price  total_sqft_int  bhk  price_per_sqft  \
# 0     3      2.0  150.0          1672.0    3     8971.291866
# 1     3      3.0  149.0          1750.0    3     8514.285714
# 2     3      2.0  150.0          1750.0    3     8571.428571
# 3     2      2.0   40.0          1250.0    2     3200.000000
# 4     2      2.0   83.0          1200.0    2     6916.666667
#
#    area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                              1                        0
# 1                              0                        1
# 2                              1                        0
# 3                              1                        0
# 4                              0                        0
#
#    area_typePlot  Area  availability_Ready To Move  ...  \
# 0                    0                           1  ...
# 1                    0                           1  ...
# 2                    0                           1  ...
# ...

# %%
df2 ['bhk'].unique()
# Out:
# array([3, 2, 1, 4, 5, 9, 6, 7, 8], dtype=int64)

# %%
df2[df2.bhk>20]
# Out:
# Empty DataFrame
# ...

# %%
df2.total_sqft_int.unique()
# Out:
# array([1672., 1750., 1250., ...,  669., 1713.,  666.])

# %%
df3=df2.copy()

# %%
df3.head()
# Out:
#    bath  balcony  price  total_sqft_int  bhk  price_per_sqft  \
# 0     3      2.0  150.0          1672.0    3     8971.291866
# 1     3      3.0  149.0          1750.0    3     8514.285714
# 2     3      2.0  150.0          1750.0    3     8571.428571
# 3     2      2.0   40.0          1250.0    2     3200.000000
# 4     2      2.0   83.0          1200.0    2     6916.666667
#
#    area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                              1                        0
# 1                              0                        1
# 2                              1                        0
# 3                              1                        0
# 4                              0                        0
#
#    area_typePlot  Area  availability_Ready To Move  ...  \
# 0                    0                           1  ...
# 1                    0                           1  ...
# 2                    0                           1  ...
# ...

# %%
df3.loc[30]
# Out:
# bath                              4.0
# balcony                           0.0
# price                           413.0
# total_sqft_int                 2750.0
# bhk                               4.0
#                                 ...
# location_Hosur Road               0.0
# location_Horamavu Banaswadi       0.0
# location_Domlur                   0.0
# location_Mahadevpura              0.0
# location_Tumkur Road              0.0
# Name: 30, Length: 108, dtype: float64

# %%
df4=df3.copy()
df4.head()
# Out:
#    bath  balcony  price  total_sqft_int  bhk  price_per_sqft  \
# 0     3      2.0  150.0          1672.0    3     8971.291866
# 1     3      3.0  149.0          1750.0    3     8514.285714
# 2     3      2.0  150.0          1750.0    3     8571.428571
# 3     2      2.0   40.0          1250.0    2     3200.000000
# 4     2      2.0   83.0          1200.0    2     6916.666667
#
#    area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                              1                        0
# 1                              0                        1
# 2                              1                        0
# 3                              1                        0
# 4                              0                        0
#
#    area_typePlot  Area  availability_Ready To Move  ...  \
# 0                    0                           1  ...
# 1                    0                           1  ...
# 2                    0                           1  ...
# ...

# %%
df4.head()
# Out:
#    bath  balcony  price  total_sqft_int  bhk  price_per_sqft  \
# 0     3      2.0  150.0          1672.0    3     8971.291866
# 1     3      3.0  149.0          1750.0    3     8514.285714
# 2     3      2.0  150.0          1750.0    3     8571.428571
# 3     2      2.0   40.0          1250.0    2     3200.000000
# 4     2      2.0   83.0          1200.0    2     6916.666667
#
#    area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                              1                        0
# 1                              0                        1
# 2                              1                        0
# 3                              1                        0
# 4                              0                        0
#
#    area_typePlot  Area  availability_Ready To Move  ...  \
# 0                    0                           1  ...
# 1                    0                           1  ...
# 2                    0                           1  ...
# ...

# %%
df4[df4.total_sqft_int/df4.bhk<300].head()
# Out:
# Empty DataFrame
# ...
